# %%
import numpy as np
import cv2

# %%
import cv2
img = cv2.imread("klon.jpg")# sondaki 0 resmi gri tonlama yapıyor
#print(img)
cv2.namedWindow("image",cv2.WINDOW_NORMAL)# resmin boyutunu değiştirmemizi sağlar
# cv2.resize(img,(600,500))  # resmin boyutunu değiştirmemizi sağlar
cv2.imshow("image",img)# resmi göstermek için

cv2.imwrite("klon1.jpg",img) # resmi kaydetmemizi sağlar klon resmini klon1 şeklinde ayrı kaydettik

cv2.waitKey(0)# resmin ekranda kalmasını sağlıyor
cv2.destroyAllWindows()

# %% [markdown]
# video 6
# En boy oranları

# %%
import cv2

def resizewithAspectRatio(img,width= None,height=None, inter =cv2.INTER_AREA):
    dimention= None
    (h,w)=img.shape[:2]

    if width is None and height is None:
        return img
     
    if width is None:
        r = height / float(h)

        dimention= (int(w*r),height)
    else:
        r = width /float(w)

        dimention=(width,int(h*r))

    return cv2.resize(img, dimention,interpolation=inter)


img=cv2.imread("klon.jpg")
img1=resizewithAspectRatio(img,width= None,height=600, inter =cv2.INTER_AREA)

cv2.imshow("original",img)
cv2.imshow("resized",img1)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# <!-- video 7 -->
# video okuma gösterme

# %%
import cv2

#cap = cv2.VideoCapture(0) # videoyu webcap den okicaksak 0 girilir
cap = cv2.VideoCapture("antalya.mp4") 
# videonun süresini bilmediğimiz için while ben durdurana kadar dönücek
while True:
     
    ret , frame = cap.read()# iki değer döndürür ilki video doğru okundumu t beya ikincisi frame 
    if ret == 0:
        break

    frame = cv2.flip(frame,1)# freamlerin yönünü değiştirir 1 y ekseninde yansıtır
    
    cv2.imshow("antalya",frame)
    key_pressed= cv2.waitKey(1)&0XFF
    if cv2.waitKey(10) and key_pressed==ord('q')&0XFF:
        break


cv2.destroyAllWindows()

# %% [markdown]
# video dosyası kaydetme

# %%
import cv2 
cap=cv2.VideoCapture(0)
fileName="C:\Users\kayan\OneDrive\Desktop\OPENCV\webcam.avi"
codec=cv2.VideoWriter_fourcc("W","M","2")
frameRate= 30
resolution=(640,480)
videoFileOutput= cv2.VideoWriter(fileName,codec,frameRate,resolution)

while True:
    ret, frame=cap.read()
    
    frame= cv2.flip(frame,1)
    videoFileOutput.write(frame)
    cv2.imshow("webcam",frame)
    key_pressed= cv2.waitKey(1)&0XFF
    if cv2.waitKey(10) and key_pressed==ord('q')&0XFF:
        break


videoFileOutput.release()
cv2.destroyAllWindows()

# %% [markdown]
# 7.KLASÖR

# %%
# ekran oluşturma
import numpy as np
import cv2
canvas =np.zeros((512,512,3), dtype=np.uint8)+255# ekran boyutlarını girdik uint 8 çizim veri tipi
cv2.imshow('Canvas',canvas) 
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#canvas = np.zeros((10,10,3),dtype=np.uint8)

canvas = np.zeros((10,10),dtype=np.uint8)
canvas[0,0]=255
canvas[0,1]=200
canvas[0,2]=100
canvas[0,3]=50

"""
canvas[0,0]=(255,255,255)
canvas[0,1]=(255,255,200)
canvas[0,2]=(255,255,150)
canvas[0,3]=(255,255,100)"""
canvas=cv2.resize(canvas,(1000,1000),interpolation=cv2.INTER_AREA)
cv2.imshow('canvas',canvas)
cv2.waitKey(0) 
cv2.destroyAllWindows()

# %%
canvas=np.zeros((512,512,3),dtype=np.uint8)+255
#line komutu ile (başlangıç bitiş renk  kalınlık)
# değerlerini girdiğimiz çizgiyi oluşturduk
cv2.line(canvas,(50,50),(512,512),(255,0,0),5)
# dikdörtgen çizmek için sol üst köşe ve sağ alt köşe konumları girilir
cv2.rectangle(canvas,(20,20),(50,50),(0,255,0),5)
# çember çizmek için merkez konumu ve yarıçapını gireriz
cv2.circle(canvas,(250,250),63,(0,0,255),5)
# içi dolu şekil için kalınlığı -1 gireriz
# üçgen için 3 köşenin kordinatlari girilir çizgi komutu kullanılır
"""p1=(10,200)
p2=(90,30)
p3=(300,200)


cv2.line(canvas,p1,p2,(0,0,0),5)
cv2.line(canvas,p2,p3,(0,0,0),5)
cv2.line(canvas,p1,p3,(0,0,0),5)"""
# daha kısa bir yol olarak çokgenler için poli line komutu kullanılır
# bunu kullanmak için numpy ile bir dizi oluşturmamız lazım
points=np.array([[110,200],[330,200],[290,220],[100,100]])


cv2.polylines(canvas,[points],True,(0,0,100),5)
# burdaki True değeri 4 noktanın birleşiminde açıklık kalırsa tamamlanmasını sağlar


# elips çizmek için merkez noktası yatay çap ve dikey çap başlangıç be bitiş açıları renk ve kalınlık 
# değerleri girilir
cv2.ellipse(canvas,(300,300),(80,20),,0,360,(255,255,0),-1)

cv2.imshow("kanvas",canvas)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
canvas=np.zeros((512,512,3),dtype=np.uint8)+255

font1=cv2.FONT_HERSHEY_SIMPLEX
font2=cv2.FONT_HERSHEY_COMPLEX
font3=cv2.FONT_HERSHEY_SCRIPT_COMPLEX
# ekrana yazı yazarken putText komutunu kullanyoruz
# ilk olarak (metin,yazının başlangıç konumu,font,yazı, büyüklüğü ,rengi ,kalınlığı)
cv2.putText(canvas,"Ali",(190,100),font3,3,(0,0,0),cv2.LINE_AA)


cv2.imshow("kanvas",canvas)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Trackbar oluştuma
import cv2
import numpy as np
def nothing(x):
    pass
img=np.zeros((512,512,3),np.uint8)
cv2.namedWindow("image")
cv2.createTrackbar('R',"image",0,255,nothing)
cv2.createTrackbar('G','image',0,255,nothing)
cv2.createTrackbar('B','image',0,255,nothing)
switch ="0: OFF, 1 : ON"
cv2.createTrackbar(switch,'image',0,1,nothing)

while True:
    cv2.imshow("image",img)
    if cv2.waitKey(1) & 0xFF==ord('q'):
        break

    r = cv2.getTrackbarPos("R","image")
    g = cv2.getTrackbarPos("G","image")
    b = cv2.getTrackbarPos("B","image")
    switchT=cv2.getTrackbarPos(switch,'image')
    if switchT==0:
        img[:]=[0,0,0]
    if switchT==1:
        img[:]=[b,g,r]
cv2.destroyAllWindows()

# %% [markdown]
# #8. klasör

# %%
# temel işlemler
import numpy as np
import cv2

img= cv2.imread("klon.jpg")
color=img[420,420]
print(color)
# pixelin rengini görme
blue = img[420,500,0]
print("blue",blue)
green=img[420,500,1]
print("green",green)
red=img[420,500,2]
print("red",red)

img[420,500,0]=250# pixelin rengini değiştirme
print("new blue",img[420,500,0])

blue1=img.item(150,200,0)
print("blue1",blue1)
img.itemset((150,200,0),172)
print("new blue1",img[150,200,0])


cv2.imshow("klon asker",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# roi -- region of interest---> ilgi alanı
import cv2
import numpy as np

img =cv2.imread("klon.jpg")

# print(img.shape[:2]) resmin boyutlarını gösterme


# resmi kırpma
roi=img[30:200,200:400]


cv2.imshow("klon asker kafası",roi)
cv2.imshow("klon asker",img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# resimleri toplama
import cv2
import numpy as np

circle = np.zeros((512,512,3),np.uint8)+255
cv2.circle(circle,(256,256),60,(255,0,0),-1)

rectangle = np.zeros((512,512,3),np.uint8)+255
cv2.rectangle(rectangle,(150,150),( 350,350),(0,0,255),-1)

add=cv2.add(circle,rectangle)
print(add[256,256])

cv2.imshow('add',add)
cv2.imshow('rectangle',rectangle)

cv2.imshow('circle',circle)


# ağırlıklı toplama






cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# ağırlıklı toplama
import cv2
import numpy as np

circle = np.zeros((512,512,3),np.uint8)+255
cv2.circle(circle,(256,256),60,(255,0,0),-1)
rectangle = np.zeros((512,512,3),np.uint8)+255
cv2.rectangle(rectangle,(150,150),( 350,350),(0,0,255),-1)

dst=cv2.addWeighted(circle,0.3,rectangle,0.7,0)


cv2.imshow('dst',dst)
cv2.imshow('circle',circle)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# renk uzayı 
import cv2

img=cv2.imread("klon.jpg")

img1=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
img2=cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
img3=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)


cv2.imshow("BGR",img)
"""cv2.imshow("RGB",img1)
cv2.imshow("HSV",img2)"""
cv2.imshow("GRAY",img3)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2

cap=cv2.VideoCapture("antalya.mp4")

while True:
    ret , frame = cap.read()
    frame=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY) # videoyu gri renge dönüştürdü

    if ret== False:
        break

    cv2.imshow('video',frame) 
    if cv2.waitKey(1) & 0xFF == ord("q"):
        break

cv2.destroyAllWindows()

# %%
import numpy as np
import cv2


cap=cv2.VideoCapture(0)

def nothing(x):
    pass

cv2.namedWindow("Trackbar")

cv2.resizeWindow("Trackbar",500,500)

cv2.createTrackbar("Lower---H","Trackbar",0,180,nothing)
cv2.createTrackbar("Lower---S","Trackbar",0,255,nothing)
cv2.createTrackbar("Lower---V","Trackbar",0,255,nothing)

cv2.createTrackbar("Upper---H","Trackbar",0,180,nothing)
cv2.createTrackbar("Upper---S","Trackbar",0,255,nothing)
cv2.createTrackbar("Upper---V","Trackbar",0,255,nothing)


cv2.setTrackbarPos("Upper---H","Trackbar",180)
cv2.setTrackbarPos("Upper---S","Trackbar",255)
cv2.setTrackbarPos("Upper---V","Trackbar",255)


while True:
    ret ,frame = cap.read()
    frame=cv2.flip(frame,1)


    frame_hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)

    Lower_h= cv2.getTrackbarPos('Lower---H',"Trackbar")
    Lower_s= cv2.getTrackbarPos('Lower---S',"Trackbar")
    Lower_v= cv2.getTrackbarPos('Lower---V',"Trackbar")    


    Upper_h= cv2.getTrackbarPos('Upper---H',"Trackbar")
    Upper_s= cv2.getTrackbarPos('Upper---S',"Trackbar")
    Upper_v= cv2.getTrackbarPos('Upper---V',"Trackbar")  


    Lower_color=np.array([Lower_h,Lower_s,Lower_v])
    Upper_color=np.array([Upper_h,Upper_s,Upper_v])

    mask= cv2.inRange(frame_hsv,Lower_color,Upper_color)


    cv2.imshow("original",frame)
    cv2.imshow("mask",mask)
    if cv2.waitKey(20) & 0xFF== ord("q"):
        break

cv2.destroyAllWindows()

# %%
# klasör 8 video 8 resimleri yumuşatmak
import numpy as np
import cv2
img_filter=cv2.imread("filter.jpg")
img_median=cv2.imread("8.1 median.png.png")
img_bilateral=cv2.imread("8.4 bilateral.png.png")

blur=cv2.blur(img_filter,(5,5))
blur2=cv2.GaussianBlur(img_filter,(5,5),cv2.BORDER_DEFAULT)

blur_m=cv2.medianBlur(img_median,5)
blur_b=cv2.bilateralFilter(img_bilateral,9,75,75)

cv2.imshow("blur",blur)
cv2.imshow("original",img_bilateral)
cv2.imshow("blur2",blur2)
cv2.imshow("blur_m",blur_m)
cv2.imshow("blur_b",blur_b)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img1=cv2.imread("bitwise1.png")
img2=cv2.imread("bitwise2.png")
# resşmlere lojik işlemler yapmak
bit_and= cv2.bitwise_and(img2,img1)

bit_or=cv2.bitwise_or(img1,img2)
bit_xor=cv2.bitwise_xor(img1,img2)
bit_not1=cv2.bitwise_not(img1)
bit_not2=cv2.bitwise_not(img2)

cv2.imshow("img1",img1)
cv2.imshow("img2",img2)
cv2.imshow("bit_or",bit_not1)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# resmi kaydırma

import numpy as np
import cv2

img=cv2.imread("klon1.jpg",0)
row,col=img.shape

M=np.float32([[1,0,10],[0,1,70]])

dst=cv2.warpAffine(img,M,(row,col))

cv2.imshow("dst",dst)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# resmi döndürme

import numpy as np
import cv2

img=cv2.imread("klon1.jpg",0)
row,col=img.shape



M=cv2.getRotationMatrix2D((col/2,row/2),90,1)

dst=cv2.warpAffine(img,M,(col,row))


cv2.imshow("dst",dst)


cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# thresholding

import numpy as np
import cv2

img=cv2.imread("klon.jpg",0)

rett,th1= cv2.threshold(img,150,200,cv2.THRESH_BINARY)

th2=cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,2) 
th3=cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_GAUSSIAN_C,cv2.THRESH_BINARY,21,2)


cv2.imshow("th1",th1)
cv2.imshow("th2",th2)
cv2.imshow("th3",th3)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import numpy as np
import cv2
# morfolojik işlemler 
img=cv2.imread("klon.jpg",0)
kernel=np.ones((5,5),np.uint8)
eresion=cv2.erode(img,kernel,iterations=1)
diletion=cv2.dilate(img,kernel,iterations=1)
opening=cv2.morphologyEx(img,cv2.MORPH_CLOSE,kernel)
tophat=cv2.morphologyEx(img,cv2.MORPH_TOPHAT,kernel)


cv2.imshow("eresion",opening)
cv2.imshow("img",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# HİSTOGRAM
import cv2
import numpy as np
from matplotlib import pyplot as plt


img= cv2.imread("smile.jpg.jpg")
#cv2.rectangle(img,(0,60),(200,150),(255,255,0),-1)

b,g,r=cv2.split(img)

cv2.imshow("img",img)


plt.hist(b.ravel(),256,[0,256])
plt.hist(g.ravel(),256,[0,256])
plt.hist(r.ravel(),256,[0,256])
plt.show()

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# köşeleri saptama
import cv2
import numpy as  np

img1=cv2.imread("15.1 text.png.png")
img=cv2.imread("15.2 contour.png.png")


gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray=np.float32(gray)
corners=cv2.goodFeaturesToTrack(gray,50,0.01,10)

corners=np.int0(corners)

for corner in corners:
    x,y=corner.ravel()
    cv2.circle(img,(x,y),3,(0,0,255),-1)


cv2.imshow("corner",img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# kenarları saptama 
# cv2.Canny(input,minThreshold,maxThreshold)
import cv2

cap=cv2.VideoCapture(0)


while 1:
    ret,frame =cap.read()
    frame=cv2.flip(frame,1)
    edges =cv2.Canny(frame,100,200)
    cv2.imshow("frame",frame)
    cv2.imshow("edges",edges)

    if cv2.waitKey(5) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
# klasör 9 
# KONTUR KAVRAMI
# convex Hull --># iç bükey şekillere dış bükey örtü
# Convexity Defects --> Dışbükey kusurlar

import cv2

img=cv2.imread("contur.png")

gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

ret,thresh=cv2.threshold(gray,127,255,cv2.THRESH_BINARY)

contur,_=cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

print(contur)

cv2.drawContours(img,contur,-1,(0,0,255),3)

cv2.imshow("contur",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# nesnelerin izini sürme

# %%
import numpy as np

import cv2


cap = cv2.VideoCapture("dog.mp4")

while 1:
    ret,frame = cap.read()

    hsv= cv2.cvtColor(frame,cv2.COLOR_BGR2HSV) # videoyu hsv formatında çevirme
    sensivitivity=15
    lower_white=np.array([0,0,255-sensivitivity]) # beyaz rengin aralıkları
    upper_white=np.array([255,sensivitivity,255])

    mask =cv2.inRange(hsv,lower_white,upper_white) # beyaz renk aralıklarına sahip bölgeye maske uygulama

    res=cv2.bitwise_and(frame,frame,mask=mask)# mask kullanmak gerekirse bunu kullanmak gerek

    cv2.imshow("frame",frame)
    cv2.imshow("mask",mask)
    cv2.imshow("result",res)

    k=cv2.waitKey(5)& 0xFF
    if k==27:
            break

# %%
# geometrik merkezi öğrenme

import cv2

img=cv2.imread("ucgen.png")

gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
_,thresh=cv2.threshold(gray,127,255,cv2.THRESH_BINARY)

M=cv2.moments(thresh)

X=int(M["m10"]/M["m00"]) # geometri merkezinin kordinat hesabı
Y=int(M["m01"]/M["m00"])

cv2.circle(img,(X,Y),5,(255,0,0),-1)

cv2.imshow("img",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# çevre alan hesabı


import cv2

img=cv2.imread("ucgen.png")

gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

ret,thresh=cv2.threshold(gray,127,255,cv2.THRESH_BINARY)

contur,l=cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)



cnt=contur[0]
M=cv2.moments(cnt)
area=cv2.contourArea(cnt)
print(area) # alan bulma
print(M['m00'])#  ikinci alan bulma stili

#çevre bulma
perimeter=cv2.arcLength(cnt,True) # şekil kapalıysa True giriyoruz değilse False

print(perimeter)

"""

cv2.imshow("orginal",img)
cv2.imshow("gray",gray)
cv2.imshow("thresh",thresh)


cv2.waitKey(0)
cv2.destroyAllWindows()"""

# %%
import cv2
import numpy as np
img=cv2.imread("map.jpg")


gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
blur=cv2.blur(gray,(3,3))
ret,thresh=cv2.threshold(blur,30,255,cv2.THRESH_BINARY)


contur,_=cv2.findContours(thresh,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)



# bunu internetten buldum convex hull ekliyor
"""for contour in contur:
    convexHull = cv2.convexHull(contour)
    cv2.drawContours(thresh, [convexHull], -1, (255, 0, 0), 2)"""


hull = []

for i in range(len(contur)):
    hull.append(cv2.convexHull(contur[i],False))

bg = np.zeros((thresh.shape[0],thresh.shape[1],3),np.uint8)

for i in range(len(contur)):
    cv2.drawContours(bg,contur,i,(255,0,0),3,8)
    cv2.drawContours(bg,hull,i,(0,255,0),1,8)


cv2.imshow("Image",bg)

cv2.imshow("thres",thresh)
cv2.imshow("orginal",img)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
# konveks kusurları

img=cv2.imread("star.png")


gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

_,thresh=cv2.threshold(gray,127,255,0)


contur,_= cv2.findContours(thresh,2,1)
cnt=contur[0]
hull=cv2.convexHull(cnt,returnPoints= False)

defects=cv2.convexityDefects(cnt,hull)

for i in range(defects.shape[0]):
    s,e,f,d=defects[i,0]
    start=tuple(cnt[s][0])
    end=tuple(cnt[e][0])
    far=tuple(cnt[f][0])
    cv2.line(img,start,end,[0,255,0],2)
    cv2.circle(img,far,5,[0,0,255],-1)

cv2.imshow("orginal",img)
cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
# 10. klasör

# %%
import cv2      # çizgileri bulma img den

import numpy as np


img= cv2.imread("line.png")


gray =cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

edges=cv2.Canny(gray,75,150)

lines=cv2.HoughLinesP(edges,1,np.pi/180,50,maxLineGap=200)


for line in lines:
    x1,y1,x2,y2=line[0]
    cv2.line(img,(x1,y1),(x2,y2),(0,255,0),2)

cv2.imshow("img",img)
cv2.imshow("gray",gray)
cv2.imshow("edges",edges)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2  # videodaki şeriti izleme
import numpy as np

cap=cv2.VideoCapture("line.mp4")

while True:
    
    red,frame=cap.read()
    
    hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)# hsv range for color şeklinde aratarak bulabiliriz
    
    lower_yellow=np.array([18,94,140],np.uint8)
    upper_yellow=np.array([48,255,255],np.uint8)

    mask=cv2.inRange(hsv,lower_yellow,upper_yellow)

    edges=cv2.Canny(mask,75,150)

    lines= cv2.HoughLinesP(edges,1,np.pi/180,50,maxLineGap=50)

    for line in lines:
          x1,y1,x2,y2=line[0]

          cv2.line(frame,(x1,y1),(x2,y2),(0,255,0),5)
    
    cv2.imshow("frame",frame)

    k=cv2.waitKey(5)& 0xFF
    if k==27:
            break

cv2.destroyAllWindows()

# %%
# çemberleri tespit etme 

import cv2
import numpy as np

img1=cv2.imread('coins.jpg')

img2=cv2.imread('balls.jpg')

gray1=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)
gray2=cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)

img1_blur=cv2.medianBlur(gray1,5)
img2_blur=cv2.medianBlur(gray2,5)

circles=cv2.HoughCircles(img2_blur,cv2.HOUGH_GRADIENT,1,img2.shape[0]/4,param1=200,param2=10,minRadius=50,maxRadius=100)

if circles is not None:
    circles=np.uint16(np.around(circles))
    for i in circles[0,:]:
        cv2.circle(img2,(i[0],i[1]),i[2],(0,255,0),2)
cv2.imshow("img",img2)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#11. klasör
# şekilleri tespit etme
import cv2
import numpy as np


font = cv2.FONT_HERSHEY_COMPLEX
font1= cv2.FONT_HERSHEY_SIMPLEX

img =cv2.imread("polygons.png")

gray =cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

_,thrashold=cv2.threshold(gray,240,255,cv2.THRESH_BINARY)

contur,_=cv2.findContours(thrashold,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

for cnt in contur:
    epsilon=0.01*cv2.arcLength(cnt,True)
    approx=cv2.approxPolyDP(cnt,epsilon,True)


    cv2.drawContours(img,[approx],0,(0),5)

    x=approx.ravel()[0]
    y=approx.ravel()[1]

    if len(approx)==3:
        cv2.putText(img,"Ucgen",(x,y),font,1,(0))
    elif len(approx)==4:
        cv2.putText(img,"dortgen",(x,y),font,1,(0))

    elif len(approx)==5:
        cv2.putText(img,"besgen",(x,y),font,1,(0))

    elif len(approx)==6:
        cv2.putText(img,"altigen",(x,y),font,1,(0))
    else:
        cv2.putText(img,"elips",(x,y),font,1,(0))


    
cv2.imshow("img",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# kameradan şekil algılama 

import cv2
import numpy as np

def nothing(x):
    pass

cap = cv2.VideoCapture(0)

cv2.namedWindow("settings")
cv2.resizeWindow("settings",500,500)
cv2.createTrackbar("Lower_Hue","settings",0,180,nothing)
cv2.createTrackbar("Lower_Sat","settings",0,255,nothing)
cv2.createTrackbar("Lower_Val","settings",0,255,nothing)
cv2.createTrackbar("Upper_Hue","settings",0,180,nothing)
cv2.createTrackbar("Upper_Sat","settings",0,255,nothing)
cv2.createTrackbar("Upper_Val","settings",0,255,nothing)

font=cv2.FONT_HERSHEY_SIMPLEX

while 1:
    ret,frame=cap.read()
    frame=cv2.flip(frame,1)
    hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)


    lh =cv2.getTrackbarPos("Lower_Hue","settings")
    ls =cv2.getTrackbarPos("Lower_Sat","settings")
    lv =cv2.getTrackbarPos("Lower_Val","settings")
    uh =cv2.getTrackbarPos("Upper_Hue","settings")
    us =cv2.getTrackbarPos("Upper_Sat","settings")
    uv =cv2.getTrackbarPos("Upper_Val","settings")
    

    Lower_color=np.array([lh,ls,lv])
    Upper_color=np.array([uh,us,uv])


    mask=cv2.inRange(hsv,Lower_color,Upper_color)


    kernel=np.ones((5,5),np.uint8)
    maks=cv2.erode(mask,kernel)

    contur,_=cv2.findContours(mask,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)


    for cnt in contur :
        area =cv2.contourArea(cnt)
        epsilon=0.01*cv2.arcLength(cnt,True)
        approx=cv2.approxPolyDP(cnt,epsilon,True)

        x=approx.ravel()[0]
        y=approx.ravel()[1]

        if area>400:
            cv2.drawContours(frame,[approx],0,(0,0,0,),5)

            if len(approx)==3:
                cv2.putText(frame,"ucgen",(x,y),font,1,(0,0,0))
            elif len(approx)==4:
                cv2.putText(frame,"dortgen",(x,y),font,1,(0,0,0))
            elif len(approx)==5:
                cv2.putText(frame,"besgen",(x,y),font,1,(0,0,0))
            elif len(approx)>6:
                cv2.putText(frame,"cokgen",(x,y),font,1,(0,0,0))

    cv2.imshow("frame",frame)
    cv2.imshow("mask",mask)
    if cv2.waitKey(3)& 0xFF == ord('q'):
        break
cap.release()
cv2.destroyAllWindows()

# %%
# arka plan çıkarma 

import cv2
import numpy as np
cap = cv2. VideoCapture("car.mp4")
_,first_frame=cap.read()
first_frame=cv2.resize(first_frame,(640,480))
first_gray=cv2.cvtColor(first_frame,cv2.COLOR_BGR2GRAY)
first_gray=cv2.GaussianBlur(first_gray,(5,5),0)

while 1:
    _,frame=cap.read()
    frame=cv2.resize(frame,(640,480))
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    gray=cv2.GaussianBlur(gray,(5,5),0)
    

    diff=cv2.absdiff(first_gray,gray)
    cv2.imshow("frame",frame)
    cv2.imshow("first_frame",first_frame)
    cv2.imshow("diff",diff)


    if cv2.waitKey(20)& 0xFF== ord('q'):
        break


cap.release()
cv2.destroyAllWindows()

# %%
# fonksiyon ile arka plan çıkarma


import cv2
import numpy as np
cap = cv2. VideoCapture("car.mp4")

subtractor= cv2.createBackgroundSubtractorMOG2(history=100,varThreshold=50,detectShadows=True)

while 1:
    _,frame=cap.read()
    frame=cv2.resize(frame,(640,480))
    mask=subtractor.apply(frame)

    cv2.imshow("frame",frame)
    cv2.imshow("mask",mask)




    if cv2.waitKey(20)& 0xFF == ord('q'):
        break


cap.release()

cv2.destroyAllWindows

# %%
# silgiyi tespit etme hsv ile


import cv2

import numpy as np
def nothing():
    pass

cap = cv2.VideoCapture("hsv.mp4")

cv2.namedWindow("Trackbar")
cv2.resizeWindow("Trackbar",500,500)


cv2.createTrackbar("LH","Trackbar",0,179,nothing)
cv2.createTrackbar("LS","Trackbar",0,255,nothing)
cv2.createTrackbar("LV","Trackbar",0,255,nothing)
cv2.createTrackbar("UH","Trackbar",0,179,nothing)
cv2.createTrackbar("US","Trackbar",0,255,nothing)
cv2.createTrackbar("UV","Trackbar",0,255,nothing)

while 1:
    _,frame=cap.read()
    frame=cv2.resize(frame,(500,350))

    hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)

    
    lh=cv2.getTrackbarPos("LH","Trackbar")
    ls=cv2.getTrackbarPos("LS","Trackbar")
    lv=cv2.getTrackbarPos("LV","Trackbar")
    uh=cv2.getTrackbarPos("UH","Trackbar")
    us=cv2.getTrackbarPos("US","Trackbar")
    uv=cv2.getTrackbarPos("UV","Trackbar")
    






    lower_blue=np.array([lh,ls,lv])
    upper_blue=np.array([uh,us,uv])

    mask=cv2.inRange(hsv,lower_blue,upper_blue)
    bitwise=cv2.bitwise_and(frame,frame,mask=mask)


    cv2.imshow("frame",frame)
    cv2.imshow("mask",mask)
    cv2.imshow("bitwise",bitwise)

    if cv2.waitKey(20) & 0xFF== ord('q'):
        break


cap.relaese()
cv2.destroyAllWindows()

# %%
# silgiyi tespit etme hsv ile


import cv2

import numpy as np
def nothing():
    pass

cap = cv2.VideoCapture(0)

cv2.namedWindow("Trackbar")
cv2.resizeWindow("Trackbar",500,500)


cv2.createTrackbar("LH","Trackbar",0,179,nothing)
cv2.createTrackbar("LS","Trackbar",0,255,nothing)
cv2.createTrackbar("LV","Trackbar",0,255,nothing)
cv2.createTrackbar("UH","Trackbar",0,179,nothing)
cv2.createTrackbar("US","Trackbar",0,255,nothing)
cv2.createTrackbar("UV","Trackbar",0,255,nothing)

while 1:
    _,frame=cap.read()
    frame=cv2.flip(frame,1)
    frame=cv2.resize(frame,(500,350))

    hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)

    
    lh=cv2.getTrackbarPos("LH","Trackbar")
    ls=cv2.getTrackbarPos("LS","Trackbar")
    lv=cv2.getTrackbarPos("LV","Trackbar")
    uh=cv2.getTrackbarPos("UH","Trackbar")
    us=cv2.getTrackbarPos("US","Trackbar")
    uv=cv2.getTrackbarPos("UV","Trackbar")
    


    lower_blue=np.array([lh,ls,lv])
    upper_blue=np.array([uh,us,uv])

    mask=cv2.inRange(hsv,lower_blue,upper_blue)
    bitwise=cv2.bitwise_and(frame,frame,mask=mask)


    cv2.imshow("frame",frame)
    cv2.imshow("mask",mask)
    cv2.imshow("bitwise",bitwise)

    if cv2.waitKey(20) & 0xFF== ord('q'):
        break


cap.relaese()
cv2.destroyAllWindows()

# %%
# tıkladığımız yerde çember oluşturma


import cv2

cap=cv2.VideoCapture(0)

cember=[]

def mouse(event,x,y,flags,params):
    if event== cv2.EVENT_LBUTTONDOWN:
        cember.append((x,y))


cv2.namedWindow("Frame")
cv2.setMouseCallback("Frame",mouse)

while 1:
    _,frame =cap.read()
    frame=cv2.flip(frame,1)

    for center in cember:
        cv2.circle(frame,center,20,(255,0,0),-1)

    cv2.imshow("Frame",frame)

    key=cv2.waitKey(1)
    if key == 27:
        break
    elif key==ord('h'):
        cember=[]

cap.relaese()
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import math 
def findMax(contur):
    max_i=0
    max_area=0
    
    for i in range(len(contur)):
        area_face=cv2.contourArea(contur[i])
        if max_area< area_face:
            max_area=area_face
            max_i=i

        try:
            cnt= contur[max_i]



        except:
            contur=[0]
            cnt=contur[0]
    return cnt
cap = cv2.VideoCapture(0)


while 1:
    ret,frame=cap.read()
    frame=cv2.flip(frame,1)

    roi=frame[50:350,200:450]# frame [y1:y2,x1,x2]

    cv2.rectangle(frame,(200,50),(450,350),(0,0,255),0)

    hsv=cv2.cvtColor(roi,cv2.COLOR_BGR2HSV)

    Lower_color=np.array([0,45,79],dtype=np.uint8)
    Upper_color=np.array([17,255,255],dtype=np.uint8)


    kernel=np.ones((3,3),np.uint8)  
    mask=cv2.inRange(hsv,Lower_color,Upper_color)
    mask =cv2.dilate(mask,kernel,iterations=1)
    mask =cv2.medianBlur(mask,15)


    contur,_=cv2.findContours(mask,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    if len(contur)> 0:
        
        c=findMax(contur)
        extLeft=tuple(c[c[:,:,0].argmin()][0])
        extRight=tuple(c[c[:,:,0].argmax()][0])
        extTop=tuple(c[c[:,:,1].argmin()][0])
        extBot=tuple(c[c[:,:,1].argmax()][0])
        cv2.circle(roi,extLeft,5,(0,0,255),2)
        cv2.circle(roi,extRight,5,(0,0,255),2)
        cv2.circle(roi,extTop,5,(0,0,255),2)
        cv2.circle(roi,extBot,5,(0,0,255),2)

        cv2.line(roi ,extLeft,extTop,(0,255,0),2)
        cv2.line(roi ,extTop,extRight,(0,255,0),2)
        cv2.line(roi ,extRight,extBot,(0,255,0),2)
        cv2.line(roi ,extBot,extLeft,(0,255,0),2)
        

        a = math.sqrt((extRight[0]-extTop[0])**2+(extRight[1]-extTop[1])**2)
        b = math.sqrt((extBot[0]-extRight[0])**2+(extBot[1]-extRight[1])**2)
        c = math.sqrt((extBot[0]-extTop[0])**2+(extBot[1]-extTop[1])**2)

        
        try:

            angel_ab=int (math.acos((a**2+b**2-c**2)/(2*b*c))*57)
            cv2.putText(roi,str(angel_ab),(extRight[0]-50,extRight[1]),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,255),2)
        except:
            
            cv2.putText(roi,"?",((extRight[0]-30),(extRight[1])),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,255),2)
    

    cv2.imshow("frame",frame)
    cv2.imshow("roi",roi)
    cv2.imshow("mask",mask)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break


    
cap.release()
cv2.destroyAllWindows()

# %%
# 14. video el özelliklerini kullanma 


import cv2
import numpy as np
import math 
def findMax(contur):
    max_i=0
    max_area=0
    
    for i in range(len(contur)):
        area_hand=cv2.contourArea(contur[i])
        if max_area< area_hand:
            max_area=area_hand
            max_i=i

        try:
            cnt= contur[max_i]



        except:
            contur=[0]
            cnt=contur[0]
    return cnt
cap = cv2.VideoCapture(0)


while 1:
    ret,frame=cap.read()
    frame=cv2.flip(frame,1)

    roi=frame[50:350,200:450]# frame [y1:y2,x1,x2]

    cv2.rectangle(frame,(200,50),(450,350),(0,0,255),0)

    hsv=cv2.cvtColor(roi,cv2.COLOR_BGR2HSV)

    Lower_color=np.array([0,45,79],dtype=np.uint8)
    Upper_color=np.array([17,255,255],dtype=np.uint8)


    kernel=np.ones((3,3),np.uint8)  
    mask=cv2.inRange(hsv,Lower_color,Upper_color)
    mask =cv2.dilate(mask,kernel,iterations=1)
    mask =cv2.medianBlur(mask,15)


    contur,_=cv2.findContours(mask,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    if len(contur)> 0:
        
        c=findMax(contur)
        extLeft=tuple(c[c[:,:,0].argmin()][0])
        extRight=tuple(c[c[:,:,0].argmax()][0])
        extTop=tuple(c[c[:,:,1].argmin()][0])
        
        cv2.circle(roi,extLeft,5,(0,0,255),2)
        cv2.circle(roi,extRight,5,(0,0,255),2)
        cv2.circle(roi,extTop,5,(0,0,255),2)
        

        cv2.line(roi ,extLeft,extTop,(0,255,0),2)
        cv2.line(roi ,extTop,extRight,(0,255,0),2)
        cv2.line(roi ,extRight,extLeft,(0,255,0),2)
        
        

        a = math.sqrt((extRight[0]-extTop[0])**2+(extRight[1]-extTop[1])**2)
        b = math.sqrt((extTop[0]-extLeft[0])**2+(extTop[1]-extLeft[1])**2)
        c = math.sqrt((extRight[0]-extLeft[0])**2+(extRight[1]-extLeft[1])**2)





        
        try:

            angel_ab=int (math.acos((a**2+c**2-b**2)/(2*c*b))*57)

            if angel_ab>70 :
                cv2.rectangle(frame,(0,0),(100,100),(255,0,0),-1)
            else:
                pass
            cv2.putText(roi,str(angel_ab),(extRight[0]-50,extRight[1]),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,255),2)
        except:
            
            cv2.putText(roi,"?",((extRight[0]-30),(extRight[1])),cv2.FONT_HERSHEY_SIMPLEX,1,(0,0,255),2)
    

    cv2.imshow("frame",frame)
    cv2.imshow("roi",roi)
    cv2.imshow("mask",mask)

    if cv2.waitKey(1) & 0xFF == ord("q"):
        break


    
cap.release()
cv2.destroyAllWindows()

# %%
# göz hareketlerini takip etme 
import cv2
import numpy as np

cap = cv2.VideoCapture("eye.mp4")




while 1:
    ret,frame= cap.read()

    roi =frame [80:210,230:450]
    rows,cols,_=roi.shape
    gray=cv2.cvtColor(roi,cv2.COLOR_BGR2GRAY)


    _,thrashold=cv2.threshold(gray,1,255,cv2.THRESH_BINARY_INV)
# sona girdiğimiz değer sadece bınary ise siyah ve grileri siyaha çevirir INV girersek siyah olan yerleri beyaz yapar



    contur,_=cv2.findContours(thrashold,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    contur= sorted(contur,key=lambda x:cv2.contourArea(x),reverse=True)
    # conturdan sonraki gelen şey sıralama ölçütü alana göre sıralıyor

    for cnt in contur:
        (x,y,w,h)=cv2.boundingRect(cnt)
        cv2.rectangle(roi,(x,y),(x+w,y+h),(0,255,0),2)
        cv2.line(roi,(x+int(w/2),0),(x+int(w/2),rows),(0,255,0),2)
        cv2.line(roi,(0,y+int(h/2)),(cols,y+int(h/2)),(0,255,0),2)
        break
    frame [80:210,230:450]=roi
    cv2.imshow("roi",roi)
    cv2.imshow("frame",frame)

    if cv2.waitKey(80)& 0xFF== ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# 12. Klasör

# %%
import cv2
import numpy as np

img1 =cv2.imread("aircraft.jpg")
img1 =cv2.resize(img1,(640,550))

img2=cv2.imread("aircraftCopy.jpg")
img2 =cv2.resize(img2,(640,550))

img3=cv2.medianBlur(img1,7)

if img1.shape== img3.shape:
    print("same size")
else:
    print("not same")

# diffrence-> farklılıkları buluyor
diff= cv2.subtract(img1,img3)

b,g,r=cv2.split(diff)

# 0 olmayan değerleri sayan fonksiyon countnonzero
if cv2.countNonZero(b)== 0 and cv2.countNonZero(g)==0 and cv2.countNonZero(r)==0:
    print ("compltely equal")

cv2.imshow("Difference",diff)
cv2.waitKey(0)
cv2.destroyAllWindows

# %%
# çözünürlük 

import numpy as np 
import cv2


windowName="Live Video"
cv2.namedWindow(windowName)

cap= cv2.VideoCapture(0)

print("width:"+str(cap.get(3))) # görüntünün enini alır 
print("High:"+str(cap.get(4))) # görüntünün  boyuu alır


cap.set(3,1280)
cap.set(4,720)

print("width:"+str(cap.get(3))) # görüntünün enini alır 
print("High:"+str(cap.get(4))) # görüntünün  boyuu alır

while True:
    _,frame=cap.read()
    frame=cv2.flip(frame,1)


    cv2.imshow(windowName,frame)
    if cv2.waitKey(1) & 0xFF== ord("q"):
        break



cap.relaese()
cv2.destroyAllWindows()

# %%
# dosyadaki blur kontrolü

import cv2

img = cv2.imread("starwarsBLUR.jpg")
blur=cv2.medianBlur(img,7)


laplacian=cv2.Laplacian(blur,cv2.CV_64F).var()

if laplacian <500 :

    print("blurlu resim")


"""cv2.imshow("img",img)
cv2.imshow("blur",blur)
cv2.waitKey(0)
cv2.destroyAllWindows()"""

# %%
# şablon arama

import cv2
import numpy as np


img=cv2.imread("starwarsBLUR.jpg")
img1=cv2.imread("starwarsKAFA.jpg")

gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

tamplateGray=cv2.cvtColor(img1,cv2.COLOR_BGR2GRAY)
w,h= tamplateGray.shape[::-1]

result =cv2.matchTemplate(gray,tamplateGray,cv2.TM_CCOEFF_NORMED)

location=np.where(result>=0.99)

for point in zip(*location[::-1]):
    cv2.rectangle(img,point,(point[0]+w,point[1]+h),(0,255,0),1)


cv2.imshow("img",img)


cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
import cv2


def nothing():
    pass

img1=cv2.imread("aircraft.jpg")

img1=cv2.resize(img1,(640,480))

img2=cv2.imread("balls.jpg")
img2=cv2.resize(img2,(640,480))

output = cv2.addWeighted(img1,0.5,img2,0.5,0)
windowName="Transition program"
cv2.namedWindow(windowName)


cv2.createTrackbar("alpha-beta",windowName,0,1000,nothing)

while True:
    cv2.imshow(windowName,output)

    alpha =cv2.getTrackbarPos("alpha-beta",windowName)/1000
    beta=1-alpha

    output=cv2.addWeighted(img1,alpha,img2,beta,0)


    if cv2.waitKey(1)==27:
        break

cv2.destroyAllWindows()

# %%
# HAAR CASCCADE 

import  cv2 

img = cv2.imread("C:\\Users\\kayan\\OneDrive\\Desktop\\OPENCV\\TestImages\\face.png")

face_cascade= cv2.CascadeClassifier("C:\\Users\\kayan\\OneDrive\\Desktop\\OPENCV\HAAR_CASCADE\\frontalface.xml")


gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)


faces= face_cascade.detectMultiScale(gray,1.3,8)

# son değer bulduğu pencere sayısı doğruluk oranını verir

for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),2)


cv2.imshow("img",img)


cv2.waitKey(0)

cv2.destroyAllWindows()

# %%
import cv2

import numpy as np


cap = cv2.VideoCapture("C:\\Users\\kayan\\OneDrive\\Desktop\\OPENCV\\TestImages\\faces.mp4")

face_cascade= cv2.CascadeClassifier("C:\\Users\\kayan\\OneDrive\\Desktop\\OPENCV\HAAR_CASCADE\\frontalface.xml")


while True:
    _,frame = cap.read()


    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)


    faces=face_cascade.detectMultiScale(gray,1.3,2)

    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,255,0),2)

    

    cv2.imshow("frame",frame)
    if cv2.waitKey(5)==27:
        break

cap.release()
cv2.destroyAllWindows()

# %%
import cv2

import numpy as np


cap = cv2.VideoCapture(0)

face_cascade= cv2.CascadeClassifier("C:\\Users\\kayan\\OneDrive\\Desktop\\OPENCV\HAAR_CASCADE\\frontalface.xml")


while True:
    _,frame = cap.read()
    frame=cv2.flip(frame,1)

    gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)


    faces=face_cascade.detectMultiScale(gray,1.3)

    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,255,0),2)

    

    cv2.imshow("frame",frame)
    if cv2.waitKey(5)==27:
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# c:\Users\kayan\OneDrive\Desktop\YAPAY_zeka_KURS\OPENCV\OPENCV_kurs_drive.ipynb Cell 61 line 1
#      <a href='vscode-notebook-cell:/c%3A/Users/kayan/OneDrive/Desktop/YAPAY_zeka_KURS/OPENCV/OPENCV_kurs_drive.ipynb#Y114sZmlsZQ%3D%3D?line=12'>13</a> frame=cv2.flip(frame,1)
#      <a href='vscode-notebook-cell:/c%3A/Users/kayan/OneDrive/Desktop/YAPAY_zeka_KURS/OPENCV/OPENCV_kurs_drive.ipynb#Y114sZmlsZQ%3D%3D?line=14'>15</a> gray = cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/kayan/OneDrive/Desktop/YAPAY_zeka_KURS/OPENCV/OPENCV_kurs_drive.ipynb#Y114sZmlsZQ%3D%3D?line=17'>18</a> faces=face_cascade.detectMultiScale(gray,1.3)
# ...

# %%
# resimden göz algılama haar cascade kullanarak


import cv2 
import numpy as np


img = cv2.imread("C:\\Users\\kayan\\OneDrive\\Desktop\\OPENCV\\TestImages\\face.png")


face_cascade= cv2.CascadeClassifier("C:\\Users\\kayan\\OneDrive\\Desktop\\OPENCV\HAAR_CASCADE\\frontalface.xml")
eye_cascade= cv2.CascadeClassifier("eye.xml")

gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

faces=face_cascade.detectMultiScale(gray,1.3,8)


for (x,y,w,h) in faces:

    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)


img2=img[y:y+h,x:x+w]

gray2=gray[y:y+h,x:x+w]

eyes= eye_cascade.detectMultiScale(gray2)

for (a,b,c,d) in eyes:
    cv2.rectangle(img2,(a,b),(a+c,b+d),(0,0,255),2)

cv2.imshow("img",img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# videodan  göz algılama
import cv2 
import numpy as np


cap=cv2.VideoCapture("eyes.mp4")
face_cascade= cv2.CascadeClassifier("C:\\Users\\kayan\\OneDrive\\Desktop\\OPENCV\HAAR_CASCADE\\frontalface.xml")
eye_cascade=cv2.CascadeClassifier("eye.xml")


while True:
    _,frame=cap.read()
    frame=cv2.resize(frame,(480,360))

    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)

    faces=face_cascade.detectMultiScale(gray,1.3,5)

    for (x,y,w,h) in faces:

        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)


    roi_frame=frame[y:y+h,x:x+w]
    roi_gray=gray[y:y+h,x:x+w]

    eyes=eye_cascade.detectMultiScale(roi_gray)

    for (a,b,c,d) in eyes:
        cv2.rectangle(roi_frame,(a,b),(a+c,b+d),(0,0,255),2)


    cv2.imshow("frame",frame)


    if cv2.waitKey(10)==27:
        break

cap.release()
cv2.destroyAllWindows()

# %%
# webcamdan göz algılama
import cv2 
import numpy as np


cap=cv2.VideoCapture(0)
face_cascade= cv2.CascadeClassifier("C:\\Users\\kayan\\OneDrive\\Desktop\\OPENCV\HAAR_CASCADE\\frontalface.xml")
eye_cascade=cv2.CascadeClassifier("eye.xml")


while True:
    _,frame=cap.read()
    
    frame=cv2.flip(frame,1)

    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)

    faces=face_cascade.detectMultiScale(gray,1.3,5)

    for (x,y,w,h) in faces:

        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),2)


    roi_frame=frame[y:y+h,x:x+w]
    roi_gray=gray[y:y+h,x:x+w]

    eyes=eye_cascade.detectMultiScale(roi_gray)

    for (a,b,c,d) in eyes:
        cv2.rectangle(roi_frame,(a,b),(a+c,b+d),(0,0,255),2)


    cv2.imshow("frame",frame)


    if cv2.waitKey(10)==27:
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# 16.klasör

# %%
# insan algılama img
import cv2


img = cv2.imread("body.jpg")

body_cascade=cv2.CascadeClassifier("fullbody.xml")


gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)


bodys=body_cascade.detectMultiScale(gray,1.8,3)


for (x,y,w,h) in bodys:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

cv2.imshow("img",img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# insan algılama video

import cv2


cap = cv2.VideoCapture("body.mp4")

body_cascade=cv2.CascadeClassifier("fullbody.xml")


while True:
    _,frame=cap.read()

    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)

    bodys=body_cascade.detectMultiScale(gray,1.4,2)
    
    for (x,y,w,h,) in bodys:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),3)
        
    cv2.imshow("frame",frame)
    if cv2.waitKey(50)==27:
        break

cap.release()
cv2.destroyAllWindows()

# %%
# araç algılama image

import cv2


img = cv2.imread("car.jpg")

body_cascade=cv2.CascadeClassifier("car.xml")


gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)


cars=body_cascade.detectMultiScale(gray,1.8,3)


for (x,y,w,h) in cars:
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)

cv2.imshow("img",img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# araç algılama video

import cv2


cap = cv2.VideoCapture("car.mp4")

cars_cascade=cv2.CascadeClassifier("car.xml")


while True:
    _,frame=cap.read()
    frame=cv2.resize(frame,(640,480))
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)

    cars=cars_cascade.detectMultiScale(gray,1.4,2)
    
    for (x,y,w,h,) in cars:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),3)
        
    cv2.imshow("frame",frame)
    if cv2.waitKey(50)==27:
        break

cap.release()
cv2.destroyAllWindows()

# %%
# gülümseme algılama img


import cv2

img = cv2.imread("smile.jpg")

face_cascade=cv2.CascadeClassifier("frontalface.xml")
smile_cascade=cv2.CascadeClassifier("smile.xml")


gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

faces=face_cascade.detectMultiScale(gray,1.3,5)

for (x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,0,255),2)

roi_gray=gray[x:x+w,y:y+h]
roi_img=img[x:x+w,y:y+h]

smiles=smile_cascade.detectMultiScale(roi_gray,1.3,3)

for (a,b,c,d) in smiles:
    cv2.rectangle(roi_img,(a,b),(a+c,b+d),(0,255,0),2)


cv2.imshow('image',img)

cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# gülümseme algılama video
import cv2

cap = cv2.VideoCapture("smile.mp4")

face_cascade=cv2.CascadeClassifier("frontalface.xml")
smile_cascade=cv2.CascadeClassifier("smile.xml")

while 1:
    _,frame=cap.read()
    frame=cv2.resize(frame,(720,640))

    gray= cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)


    faces=face_cascade.detectMultiScale(gray,1.3,5)

    for (x,y,w,h) in faces:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,0,255),2)

        roi_gray=gray[x:x+w,y:y+h]
        roi_frame=frame[x:x+w,y:y+h]

        smiles=smile_cascade.detectMultiScale(roi_gray,1.4,4)

        for (a,b,c,d) in smiles:
            cv2.rectangle(roi_frame,(a,b),(a+c,b+d),(0,255,0),2)

    cv2.imshow("frame",frame)
    if cv2.waitKey(5)==27:
        break
cap.release()
cv2.destroyAllWindows()

# %%
# gülümseme algılama webcam
import cv2


vid = cv2.VideoCapture(0)

smile_cascade = cv2.CascadeClassifier('smile.xml')
face_cascade = cv2.CascadeClassifier('frontalface.xml')


while 1:
    ret,frame = vid.read()
    frame =cv2.flip(frame,1)
    
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray,1.5,9)
    
    for (x,y,w,h) in faces:

        cv2.rectangle(frame,(x,y),(x+w,y+h),(0,0,255),2)
        roi_gray = gray[x:x+w,y:y+h]
        roi_img = frame[x:x+w,y:y+h]

        smiles = smile_cascade.detectMultiScale(roi_gray,1.5,9)
        for (ex,ey,ew,eh) in smiles:
            cv2.rectangle(roi_img,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)

    cv2.imshow('videos',frame)

    if cv2.waitKey(5) & 0xFF == ord('q'):
        break

vid.release()
cv2.destroyAllWindows()

# %% [markdown]
# 19.klasör

# %%
# araç algılama kendi cascademiz ile

import cv2


cap = cv2.VideoCapture("car.mp4")

cars_cascade=cv2.CascadeClassifier("MYcarCascade.xml")


while True:
    _,frame=cap.read()
    frame=cv2.resize(frame,(640,480))
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)

    cars=cars_cascade.detectMultiScale(gray,1.4,2)
    
    for (x,y,w,h,) in cars:
        cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),3)
        
    cv2.imshow("frame",frame)
    if cv2.waitKey(50)==27:
        break

cap.release()
cv2.destroyAllWindows()

# %%
# resimdeki metni okuma


from PIL import Image

import pytesseract

im = Image.open("text.png")
text = pytesseract.image_to_string(im,lang="eng")
print(text)

# %%
# resimden plaka okuma

import cv2
import numpy as np
import pytesseract

import imutils


img = cv2.imread("plaka.jpg")

gray= cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

filter=cv2.bilateralFilter(gray,6,250,350)

edged=cv2.Canny(filter,30,200)

contur=cv2.findContours(edged,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)

cnts=imutils.grab_contours(contur)

cnts=sorted(cnts,key=cv2.contourArea,reverse=True)[:10]# kordinatları alanlara göre ters şekilde srala

screen=None

for c in cnts:
    epsilon=0.018*cv2.arcLength(c,True)# formül 
    approx=cv2.approxPolyDP(c,epsilon,True)

    if len(approx) ==4:
        screen=approx
        break

mask=np.zeros(gray.shape,np.uint8)
new_img=cv2.drawContours(mask,[screen],0,(255,255,255),-1)
new_img=cv2.bitwise_and(img,img,mask=mask)

(x,y)=np.where(mask==255)


(topx,topy)=(np.min(x),np.min(y))
(botx,boty)=(np.max(x),np.max(y))

cropped=gray[topx:botx+1,topy:boty+1]

text=pytesseract.image_to_string(cropped,lang="eng")
print(text)


cv2.imshow("img",cropped)



cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# trafikteki araçlari sayma
import cv2
import numpy as np

cap= cv2.VideoCapture("trafik.avi")
backsub=cv2.createBackgroundSubtractorMOG2()
c=0

while True:
    _,frame=cap.read()
    fgmask=backsub.apply(frame)# araçları arka plandan ayırdı

    cv2.line(frame,(50,0),(50,300),(255,0,0),2)
    cv2.line(frame,(70,0),(70,300),(255,0,0),2)

    contur,hi=cv2.findContours(fgmask,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    try: hi=hi[0]
    except:hi=[]
    


    for contour,hier in zip(contur,hi):
            (x,y,w,h) = cv2.boundingRect(contour)
            if w>40 and h >40:
                cv2.rectangle(frame,(x,y),(x+w,y+h),(255,0,0),3)
                if x>50 and x<70:
                    c+=1

    cv2.putText(frame,"car: "+str(c),(90,100),cv2.FONT_HERSHEY_SIMPLEX,2,(0,0,255),2,cv2.LINE_AA)
    cv2.imshow("counter",frame)

    cv2.imshow("frame",fgmask)

    if cv2.waitKey(40) & 0xFF==ord('q'):
            break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# 23. klasör

# %%
import cv2
import numpy as np
import math

cap=cv2.VideoCapture(0)

while 1:
        _,frame=cap.read()
        frame=cv2.flip(frame,1)
        kernel=np.ones((3,3),np.uint8)

        roi=frame[100:300,100:300]
        cv2.rectangle(frame,(100,100),(300,300),(0,0,255),0)
        
        hsv=cv2.cvtColor(roi,cv2.COLOR_BGR2HSV)
        lower_skin=np.array([0,20,70],dtype=np.uint8)
        upper_skin=np.array([20,255,255],dtype=np.uint8)


        mask=cv2.inRange(hsv,lower_skin,upper_skin)

        mask= cv2.dilate(mask,kernel,iterations=4)

        mask=cv2.GaussianBlur(mask,(5,5),100)

        contur,_=cv2.findContours(mask,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
        cnt=max(contur,key=lambda x:cv2.contourArea(x))

        epsilon=0.0005*cv2.arcLength(cnt,True)  # conturlara daha iyi yaklaşmayı sağlar
        approx=cv2.approxPolyDP(cnt,epsilon,True)


        hull=cv2.convexHull(cnt)

        areaHull=cv2.contourArea(hull) # alanlarına eriştik
        areaHand=cv2.contourArea(cnt)

        areaRatio=((areaHull-areaHand)/areaHand)*100


        hull=cv2.convexHull(approx,returnPoints=False)

        defects=cv2.convexityDefects(approx,hull)

        l=0

        for i in range(defects.shape[0]):
            s,e,f,d=defects[i,0]
            start=tuple(approx[s][0])
            end=tuple(approx[e][0])
            far=tuple(approx[f][0])

            a= math.sqrt((end[0]-start[0])**2+(end[1]-start[1])**2)
            b= math.sqrt((far[0]-start[0])**2+(far[1]-start[1])**2)
            c= math.sqrt((end[0]-far[0])**2+(end[1]-far[1])**2)

            alan=(a+b+c)/2

            ar=math.sqrt(alan*(alan-a)*(alan-b)*(alan-c))
            v=(2*ar)/a

            # cosinüs teoremi ile açı bulduk
            angle = math.acos((b**2 + c**2 - a**2)/(2*b*c)) * 57
            if angle <=90 and v>30:
    
                l+=1
                cv2.circle(roi,far,3,(255,0,0),-1)
            
            cv2.line(roi,start,end,(255,0,0),1)
        l+=1

        font = cv2.FONT_HERSHEY_SIMPLEX

        if l==1:
            if areaHand<2000:
                cv2.putText(frame,'put your hands in the box:',(0,50),font,1,(0,0,255),3,cv2.LINE_AA)
                cv2.putText(frame,'Put your hand in the box',(0,50), font, 1, (0,0,255), 3, cv2.LINE_AA)
            else:
                if areaRatio <12:
                    cv2.putText(frame,'0',(0,50),font,2,(0,0,255),3,cv2.LINE_AA)        
                elif areaRatio <17.5:
                    cv2.putText(frame,'best luck',(0,50),font,2,(0,0,255),3,cv2.LINE_AA)
                else:
                    
                    cv2.putText(frame,'1',(0,50),font,2,(0,0,255),3,cv2.LINE_AA)
        elif l==2:
            cv2.putText(frame,'2',(0,50),font,2,(0,0,255),3,cv2.LINE_AA)
        elif l==3:
            if areaRatio <27:
                cv2.putText(frame,'3',(0,50),font,2,(0,0,255),3,cv2.LINE_AA)
            else:
                cv2.putText(frame,'Ok',(0,50),font,2,(0,0,255),3,cv2.LINE_AA)
        
        elif l==4:
            cv2.putText(frame,'4',(0,50),font,2,(0,0,255),3,cv2.LINE_AA)

        elif l==5:
            cv2.putText(frame,'5',(0,50),font,2,(0,0,255),3,cv2.LINE_AA)
        
        elif l==6:
            cv2.putText(frame,'reposition',(0,50),font,2,(0,0,255),3,cv2.LINE_AA)

        else:
            cv2.putText(frame,'reposition',(0,50),font,2,(0,0,255),3,cv2.LINE_AA)


        cv2.imshow('mask',mask)
        cv2.imshow('frame',frame)
   
        k=cv2.waitKey(5) & 0xFF
        if k==27:
            break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# 24.klasör

# %%
#ekrana yazı yazma

import numpy as np
import cv2
from collections import deque # listeleme işlemi yapar
cap=cv2.VideoCapture(0)
kernel=((5,5),np.uint8)
lower_blue=np.array([100,60,60])
upper_blue=np.array([140,255,255])

blue_points=[deque(maxlen=512)]
green_points=[deque(maxlen=512)]
red_points=[deque(maxlen=512)]
yellow_points=[deque(maxlen=512)]

blue_index=0
green_index=0
red_index=0
yellow_index=0

colors=[(255,0,0),(0,255,0),(0,0,255),(0,255,255)]

color_index=0



paintWindow=np.zeros((471,636,3))+255
paintWindow=cv2.rectangle(paintWindow,(40,1),(140,65),(0,0,0),2)
paintWindow=cv2.rectangle(paintWindow,(160,1),(255,65),colors[0],-1)
paintWindow=cv2.rectangle(paintWindow,(275,1),(370,65),colors[1],-1)
paintWindow=cv2.rectangle(paintWindow,(390,1),(485,65),colors[2],-1)
paintWindow=cv2.rectangle(paintWindow,(505,1),(600,65),colors[3],-1)

font=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(paintWindow,'Clear ALL',(49,33),font,0.5,(0,0,0),2,cv2.LINE_AA)
cv2.putText(paintWindow,'BLUE',(185,33),font,0.5,(255,255,255),2,cv2.LINE_AA)
cv2.putText(paintWindow,'GREEN',(298,33),font,0.5,(255,255,255),2,cv2.LINE_AA)
cv2.putText(paintWindow,'RED',(420,33),font,0.5,(255,255,255),2,cv2.LINE_AA)
cv2.putText(paintWindow,'YELLOW',(520,33),font,0.5,(255,255,255),2,cv2.LINE_AA)

cv2.namedWindow("Paint")

while 1:
    _,frame=cap.read()
    frame=cv2.flip(frame,1)
    kernel=((5,5),np.uint8)
    hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)

    frame=cv2.rectangle(frame,(40,1),(140,65),(0,0,0),2)
    frame=cv2.rectangle(frame,(160,1),(255,65),colors[0],-1)
    frame=cv2.rectangle(frame,(275,1),(370,65),colors[1],-1)
    frame=cv2.rectangle(frame,(390,1),(485,65),colors[2],-1)
    frame=cv2.rectangle(frame,(505,1),(600,65),colors[3],-1)

    font=cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame,'Clear ALL',(49,33),font,0.5,(0,0,0),2,cv2.LINE_AA)
    cv2.putText(frame,'BLUE',(185,33),font,0.5,(255,255,255),2,cv2.LINE_AA)
    cv2.putText(frame,'GREEN',(298,33),font,0.5,(255,255,255),2,cv2.LINE_AA)
    cv2.putText(frame,'RED',(420,33),font,0.5,(255,255,255),2,cv2.LINE_AA)
    cv2.putText(frame,'YELLOW',(520,33),font,0.5,(255,255,255),2,cv2.LINE_AA)




    mask = cv2.inRange(hsv,lower_blue,upper_blue)

    mask = cv2.erode(mask,(5,5),iterations =2)
    mask = cv2.morphologyEx(mask,cv2.MORPH_OPEN,(5,5))
    mask = cv2.dilate(mask,(5,5),iterations = 1)

    contur,_ = cv2.findContours(mask,cv2.RETR_TREE,cv2.CHAIN_APPROX_SIMPLE)
    center=None

    if len(contur)>0:
        max_contours = sorted(contur, key = cv2.contourArea, reverse=True)[0]
        ((x,y),radius) = cv2.minEnclosingCircle(max_contours)
        cv2.circle(frame,(int(x),int(y)),int(radius),(255,255,0),3)

        M= cv2.moments(max_contours)
        center= (int(M["m10"]/M["m00"]),int(M["m01"]/M["m00"]))

        if center[1] <=65 :
            if 40 <= center[0] <=140:
                blue_points=[deque(maxlen=512)]
                green_points=[deque(maxlen=512)]
                red_points=[deque(maxlen=512)]
                yellow_points=[deque(maxlen=512)]

                blue_index=0
                green_index=0
                red_index=0
                yellow_index=0

                paintWindow[67:,:,:]=255

            elif  160 <= center[0] <=255:
                color_index=0

            elif  275 <= center[0] <=370:
                color_index=1
            elif  390 <= center[0] <=485:
                color_index=2

            elif  505 <= center[0] <=600:
                color_index=3

        else :

    
            if  color_index== 0:
                blue_points[blue_index].appendleft(center)
            elif   color_index== 1:
                green_points[green_index].appendleft(center)
            elif   color_index== 2:   
                red_points[red_index].appendleft(center)
            elif    color_index== 3:   
                yellow_points[yellow_index].appendleft(center)

    else:
        blue_points.append(deque(maxlen=512))
        blue_index+=1
        green_points.append(deque(maxlen=512))
        green_index+=1
        red_points.append(deque(maxlen=512))
        red_index+=1
        yellow_points.append(deque(maxlen=512))
        yellow_index+=1

    points=[blue_points,green_points,red_points,yellow_points]

    for i in range(len(points)):
        for j in range (len(points[i])):
            for k in range (len(points[i][j])):
                if points[i][j][k-1] is None or points[i][j][k] is None:
                    continue
                cv2.line(frame,points[i][j][k-1],points[i][j][k],colors[i],2)
                cv2.line(paintWindow,points[i][j][k-1],points[i][j][k],colors[i],2)




    cv2.imshow("frame",frame)
    cv2.imshow("Paint",paintWindow)

    if cv2.waitKey(5)==27:
        break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# 25. klasör

# %%
import numpy as np

x = np.array([1,2,3],np.int16)
print (x)

# %%
# gerekli paketleri(kütüphaneleri) içe aktarıyoruz
import cv2                     
import imutils              
import numpy as np

coin = cv2.imread("coin1.jpg")    
  


cv2.imshow("coin",coin)  


cv2.waitKey(0) 
cv2.destroyAllWindows()
